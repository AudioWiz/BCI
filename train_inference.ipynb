# %% [markdown]
# <a href="https://colab.research.google.com/github/AudioWiz/BCI/blob/main/train_inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/clementgr/stain-normalization.git
# !rm -r /content/sample_data
# !pip install gdown
# Out:
# Cloning into 'stain-normalization'...
# remote: Enumerating objects: 233, done.
# remote: Counting objects: 100% (233/233), done.
# remote: Compressing objects: 100% (178/178), done.
# remote: Total 233 (delta 129), reused 141 (delta 49), pack-reused 0
# Receiving objects: 100% (233/233), 12.55 MiB | 17.86 MiB/s, done.
# Resolving deltas: 100% (129/129), done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import os
os.chdir('stain-normalization')

# %%
# !sh scripts/train_test_data_download.sh
# Out:
# /usr/local/lib/python3.9/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1640FtfGv1gQ3gdsEo5chEWb23qmJlhXm
# To: /content/stain-normalization/trainA.zip
# 100% 548M/548M [00:02<00:00, 210MB/s]
# /usr/local/lib/python3.9/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1-9D2Yn_JDprzv_VTugFfXKsaah7ECEaN
# To: /content/stain-normalization/trainB.zip
# 100% 526M/526M [00:02<00:00, 240MB/s]
# /usr/local/lib/python3.9/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
# ...

# %%
# !sh scripts/checkpoint_download.sh
# Out:
# /usr/local/lib/python3.9/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1QgmA8FHDv-oDcBJXeQ8Ql99WAcb0tnyj
# To: /content/stain-normalization/checkpoints/pretrained.zip
# 100% 1.68G/1.68G [00:06<00:00, 258MB/s]

# %% [markdown]
# train

# %%
# !python train.py --config config/train_config.json
# Out:
# ------------ Options -------------
# batchSize: 4
# beta1: 0.5
# checkpoints_dir: checkpoints
# continue_train: False
# cropSize: 256
# dataroot: data
# dataset_mode: unaligned
# display_id: 0
# display_port: 0
# display_single_pane_ncols: 0
# display_winsize: 256
# epoch_count: 1
# gpu_ids: [0]
# identity: 0.5
# init_type: normal
# initialized: True
# input_nc: 3
# isTrain: True
# lambda_A: 10.0
# lambda_B: 10.0
# loadSize: 256
# lr: 0.0002
# lr_decay_iters: 50
# lr_policy: step
# max_dataset_size: 100000
# model: cycle_gan
# nThreads: 1
# n_layers_D: 3
# name: experiment_name
# ndf: 64
# ngf: 64
# niter: 10
# niter_decay: 10
# no_dropout: False
# no_flip: False
# no_html: False
# no_lsgan: False
# norm: instance
# output_nc: 3
# phase: train
# pool_size: 50
# print_freq: 100
# resize_or_crop: crop
# save_epoch_freq: 1
# save_latest_freq: 5000
# save_log: True
# serial_batches: False
# shuffle: True
# update_html_freq: 1000
# which_direction: AtoB
# which_epoch: latest
# ...

# %% [markdown]
# inference

# %%
# !python inference.py --config config/inference_config.json
# Out:
# remove existing result dir? y
# #inference images = 912
# cycle_gan
# initialization method [normal]
# initialization method [normal]
# model CycleGAN_inference was created
# --- 110.64 seconds ---

# %%
# !zip -r /content/stain-normalization/results.zip /content/stain-normalization/results
# Out:
#   adding: content/stain-normalization/results/ (stored 0%)
#   adding: content/stain-normalization/results/fake_Hamamatsu A10_01A_x=1024_y=256.png (deflated 0%)
#   adding: content/stain-normalization/results/fake_Hamamatsu A07_02B_x=256_y=1280.png (deflated 0%)
#   adding: content/stain-normalization/results/fake_Hamamatsu A10_00B_x=512_y=1280.png (deflated 0%)
#   adding: content/stain-normalization/results/fake_Hamamatsu A04_07C_x=1024_y=768.png (deflated 0%)
#   adding: content/stain-normalization/results/fake_Hamamatsu A04_07C_x=0_y=512.png (deflated 0%)
#   adding: content/stain-normalization/results/fake_Hamamatsu A11_06D_x=768_y=1280.png (deflated 0%)
#   adding: content/stain-normalization/results/fake_Hamamatsu A04_00B_x=1024_y=1280.png (deflated 0%)
#   adding: content/stain-normalization/results/fake_Hamamatsu A11_01C_x=1024_y=512.png (deflated 0%)
#   adding: content/stain-normalization/results/fake_Hamamatsu A11_01A_x=768_y=1024.png (deflated 0%)
# ...
